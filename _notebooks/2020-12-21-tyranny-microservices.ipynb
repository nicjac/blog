# %% [markdown]
# # The tyranny of microservices
# > How I learned to embrace the Monolith/Citadel
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [jupyter]
# - image: images/chart-preview.png

# %% [markdown]
# WIP
